# %%
from pycaret.datasets import *

# %%
# this calls the list of datasets
get_data(dataset='index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
# open es specific dataset
from pycaret.datasets import get_data
dataset = get_data('cancer')
# Out:
#    Class  age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0      0    5          1           1          1          2          1       3
# 1      0    5          4           4          5          7         10       3
# 2      0    3          1           1          1          2          2       3
# 3      0    6          8           8          1          3          4       3
# 4      0    4          1           1          3          2          1       3
#
#    breast-quad  irradiat
# 0            1         1
# 1            2         1
# 2            1         1
# 3            7         1
# 4            1         1

# %%
import pandas as pd
pd.unique(dataset['Class'])
# Out:
# array([0, 1], dtype=int64)

# %%
# import classification module and setup environment, * imports all libraries
from pycaret.classification import *

# %%
# for preprocessing use set up and add remove_outliers = True (sillent=True, is not more supported)
# always on power BI to cancel any dropdown,
# that can corrupt the training process later on
clf1 = setup(dataset, target = 'Class', remove_outliers = True)
# Out:
# <style type="text/css">
# #T_07302_row8_col1, #T_07302_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_07302">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07302_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_07302_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07302_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07302_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_07302_row0_col1" class="data row0 col1" >2861</td>
#     </tr>
#     <tr>
#       <th id="T_07302_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07302_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_07302_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_07302_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# we can create also a model we want and save it, for instant call, instead of creating it,
# with every refresh of power query
xgboost = create_model("xgboost")
xgboost
# Out:
# <style type="text/css">
# #T_1c98e_row10_col0, #T_1c98e_row10_col1, #T_1c98e_row10_col2, #T_1c98e_row10_col3, #T_1c98e_row10_col4, #T_1c98e_row10_col5, #T_1c98e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1c98e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c98e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1c98e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1c98e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1c98e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1c98e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1c98e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1c98e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned_xgboost = tune_model(xgboost)
# Out:
# <style type="text/css">
# #T_7b236_row10_col0, #T_7b236_row10_col1, #T_7b236_row10_col2, #T_7b236_row10_col3, #T_7b236_row10_col4, #T_7b236_row10_col5, #T_7b236_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7b236">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b236_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7b236_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7b236_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7b236_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7b236_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7b236_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7b236_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
xgboost = finalize_model(tuned_xgboost)

save_model(xgboost, r'C:\Users\emili\OneDrive\Data_science_learning\Power_BI\ML_AI_and_Power_BI\7_Classification_models_from_outside_to_Power_BI\Exercise\Notebook/tuned_xgboost')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\emili\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age', 'menopause', 'tumor-size',
#                                               'inv-nodes', 'node-caps',
#                                               'deg-malig', 'breast',
#                                               'breast-quad', 'irradiat'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                mis...
# ...
